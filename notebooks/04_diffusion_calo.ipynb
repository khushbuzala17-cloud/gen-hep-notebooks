# %% [markdown]
# # 04 · Diffusion for Calorimeter Showers
#
# **Generative Modelling for HEP** — notebook 4 of 6.
#
# So far the physics modality has been **jets** (point clouds). Here we switch to
# the other big LHC data modality: **calorimeter showers**. When a particle hits
# the calorimeter it deposits energy across a grid of cells — effectively a small
# *energy image* `(1, H, W)`. The **CaloChallenge** asks us to *generate* these
# showers fast, as a surrogate for slow Geant4 simulation.
#
# A shower is not unconditional: a 100 GeV particle deposits far more energy than a
# 1 GeV one. So we build a **conditional diffusion model** — a `diffusers` UNet
# that takes the **incident energy** as a condition (via class embeddings on
# energy bins) and learns to denoise showers *for that energy*.
#
# We'll then probe the generator the way a physicist would:
#
# - **energy response** — does generated total energy track the requested energy?
# - **calibration / linearity** — what is the deposited-vs-incident ratio?
# - a **1-D summary distribution** (our recurring physics spine) — generated vs
#   real total-energy spectra.
#
# > You complete the cells marked **Exercise** — most ask for a number, one asks
# > you to **submit a plot**, and one a short **written reflection**. Everything
# > else runs as-is.

# %%
# %load_ext cadence
# Loads the cadence magics + the input transformer that comments out
# `# cadence:starter` regions, so the scaffold placeholders never run.
# Out:
# The cadence extension is already loaded. To reload it, use:
#   %reload_ext cadence

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

import sys; sys.path.insert(0, "..")
from src.seeds import set_seed
from src.train import get_device, to_loader, train
from src.data import load_calochallenge
from src.diffusion import make_unet, make_scheduler

SEED = 0
IMG = 16             # showers are (1, IMG, IMG) energy images
N_EBINS = 10         # incident-energy is bucketed into this many class bins
EPOCHS = 40          # diffusion conditioning needs real training — a few minutes on
                     # a GPU. This notebook is GPU-oriented; on CPU it is slow AND the
                     # short run may not fully learn the conditioning (that is a lesson too).
BATCH = 128
set_seed(SEED)
device = get_device()
print(f"device={device}  img={IMG}x{IMG}  energy_bins={N_EBINS}  epochs={EPOCHS}")
# Out:
# device=cpu  img=16x16  energy_bins=10  epochs=40

# %% [markdown]
# ## Part A · The calorimeter dataset
#
# `load_calochallenge` returns `(showers, incident_energy)`: showers are
# `(N, 1, H, W)` energy images (GeV per cell) and `incident_energy` is a 1-D array
# of incident particle energies (GeV). If the real CaloChallenge HDF5 isn't mounted
# we fall back to a synthetic stand-in with the same shapes and the same physics:
# total deposited energy scales with the incident energy.
#
# Two preprocessing choices matter for diffusion:
#
# 1. **Normalise** the energy images to roughly `[-1, 1]` (diffusion assumes data
#    near unit scale), keeping the per-shower scale so we can invert it later.
# 2. **Bin** the continuous incident energy into `N_EBINS` discrete classes — the
#    UNet's `class_embed` conditioning takes an integer label per sample.

# %%
showers, incident = load_calochallenge(path=None, max_showers=4000)
showers = showers.astype("float32")
incident = incident.astype("float32")
print("showers:", tuple(showers.shape), "| incident GeV range:",
      round(float(incident.min()), 1), "->", round(float(incident.max()), 1))

# Per-dataset normalisation to ~[-1, 1]: log1p tames the huge dynamic range of
# energy deposits, then we scale by the global max. `to_image`/`from_image`
# round-trip between physical GeV and the network's normalised space.
LOG_MAX = float(np.log1p(showers).max())

def to_image(e_gev):
    return (np.log1p(e_gev) / LOG_MAX) * 2.0 - 1.0      # GeV -> [-1, 1]

def from_image(x):
    x = np.asarray(x)
    return np.expm1(((x + 1.0) / 2.0) * LOG_MAX)        # [-1, 1] -> GeV

X = to_image(showers)                                   # (N, 1, IMG, IMG)

# Bin incident energy into N_EBINS classes (uniform in log-energy).
log_e = np.log(incident)
EDGES = np.linspace(log_e.min(), log_e.max() + 1e-6, N_EBINS + 1)

def energy_to_bin(e_gev):
    return np.clip(np.digitize(np.log(e_gev), EDGES) - 1, 0, N_EBINS - 1)

def bin_to_energy(b):
    # representative (geometric-centre) energy of a bin
    lo, hi = EDGES[b], EDGES[b + 1]
    return float(np.exp(0.5 * (lo + hi)))

ebin = energy_to_bin(incident).astype("int64")
print("energy bins populated:", len(np.unique(ebin)), "/", N_EBINS)
# Out:
# [data] no CaloChallenge path given; using synthetic showers
# showers: (4000, 1, 16, 16) | incident GeV range: 1.0 -> 100.0
# energy bins populated: 10 / 10

# %% [markdown]
# We pair each shower image with its energy-bin label in the loader, build the
# conditional UNet (`class_embed=True`, `num_classes=N_EBINS`), and a cosine DDPM
# scheduler. We optionally warm-start from `checkpoints/calo_diffusion.pt`.

# %%
from pathlib import Path
from torch.utils.data import DataLoader, TensorDataset

X_t = torch.as_tensor(X, dtype=torch.float32)
y_t = torch.as_tensor(ebin, dtype=torch.long)
calo_loader = DataLoader(TensorDataset(X_t, y_t), batch_size=BATCH, shuffle=True)

unet = make_unet(sample_size=IMG, in_channels=1, base_channels=32,
                 class_embed=True, num_classes=N_EBINS).to(device)
scheduler = make_scheduler(num_train_timesteps=1000)
T_TRAIN = scheduler.config.num_train_timesteps

CKPT = Path("..") / "checkpoints" / "calo_diffusion.pt"
if CKPT.exists():
    unet.load_state_dict(torch.load(CKPT, map_location=device))
    print("loaded checkpoint:", CKPT)
else:
    print("no checkpoint; will train a small model in the next exercise")

print("UNet params:", sum(p.numel() for p in unet.parameters()))
# Out:
# no checkpoint; will train a small model in the next exercise
# UNet params: 1106945

# %% [markdown]
# ### Exercise 1 — The energy-conditioned training step
#
# Diffusion training is "predict the noise". For a batch of shower images `x0` and
# their energy-bin labels `labels`:
#
# 1. sample random timesteps `t` and Gaussian `noise`,
# 2. form the noisy images with `scheduler.add_noise(x0, noise, t)`,
# 3. ask the UNet to predict the noise **given the energy condition** — pass the
#    labels via `class_labels=labels`,
# 4. return the **MSE** between predicted and true noise.
#
# Implement `calo_step`, train for `EPOCHS`, and report the **final epoch's mean
# training loss** as `final_loss` (a number).

# %%
# cadence:checkpoint ex1-calo-train
# cadence:starter
def calo_step(model, batch):
    x0, labels = batch                       # images in [-1,1], energy-bin ints
    noise = torch.randn_like(x0)
    t = torch.randint(0, T_TRAIN, (x0.shape[0],), device=x0.device).long()
    # 1) noise the images to step t with the scheduler:
    noisy = ...
    # 2) predict the noise, CONDITIONED on the energy bin (this is the whole point):
    pred = ...
    # 3) the noise-prediction MSE:
    return ...
# cadence:end
# cadence:hint noisy = scheduler.add_noise(x0, noise, t); pred = model(noisy, t, class_labels=labels).sample; return F.mse_loss(pred, noise).

def calo_step(model, batch):
    x0, labels = batch
    noise = torch.randn_like(x0)
    t = torch.randint(0, T_TRAIN, (x0.shape[0],), device=x0.device).long()
    noisy = scheduler.add_noise(x0, noise, t)
    pred = model(noisy, t, class_labels=labels).sample
    return F.mse_loss(pred, noise)

if CKPT.exists():
    history = train(unet, calo_loader, calo_step, epochs=1, lr=1e-4, device=device)
else:
    history = train(unet, calo_loader, calo_step, epochs=EPOCHS, lr=2e-4, device=device)
final_loss = round(float(history[-1]), 4)
print("final noise-MSE loss:", final_loss)

final_loss
# Out:
# train:   0%|          | 0/40 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 27
#      23
#      24 if CKPT.exists():
#      25     history = train(unet, calo_loader, calo_step, epochs=1, lr=1e-4, device=device)
#      26 else:
# ---> 27     history = train(unet, calo_loader, calo_step, epochs=EPOCHS, lr=2e-4, device=device)
#      28 final_loss = round(float(history[-1]), 4)
#      29 print("final noise-MSE loss:", final_loss)
#      30
#
# File ~/teaching/ml4hep/gen-hep-notebooks/notebooks/../src/train.py:46, in train(model, loader, step_fn, epochs, lr, device, optimizer, progress)
#      44 loss = step_fn(model, batch)
#      45 opt.zero_grad()
# ---> 46 loss.backward()
#      47 opt.step()
#      48 running += float(loss) * (len(batch[0]) if isinstance(batch, (list, tuple)) else len(batch))
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/autograd/__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/autograd/graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Part B · Sampling conditioned on energy
#
# To generate a shower at a chosen energy bin we run the reverse diffusion loop,
# passing the same `class_labels` at every denoising step. We provide a
# `sample_showers(bins)` helper that returns generated showers **in physical GeV**
# (it inverts the `from_image` normalisation and floors tiny negatives to zero).

# %%
@torch.no_grad()
def sample_showers(bins, n_steps=50):
    """Generate one shower per entry in `bins` (an int array of energy bins).
    Returns showers in physical GeV, shape (len(bins), 1, IMG, IMG)."""
    unet.eval()
    labels = torch.as_tensor(np.asarray(bins), dtype=torch.long, device=device)
    x = torch.randn(len(labels), 1, IMG, IMG, device=device)
    scheduler.set_timesteps(n_steps)
    for t in scheduler.timesteps:
        eps = unet(x, t, class_labels=labels).sample
        x = scheduler.step(eps, t, x).prev_sample
    gev = from_image(x.cpu().numpy())
    return np.clip(gev, 0.0, None)

_demo = sample_showers(np.array([0, N_EBINS // 2, N_EBINS - 1]))
print("sampled showers:", _demo.shape,
      "| total GeV per shower:", np.round(_demo.sum((1, 2, 3)), 1))
# Out:
# sampled showers: (3, 1, 16, 16) | total GeV per shower: [342.8 340.4 376.8]

# %% [markdown]
# ### Exercise 2 — Energy response (the key conditioning test)
#
# A conditional generator is only useful if the condition *takes*. Request a spread
# of incident energies, generate a shower for each, and measure the **energy
# response**: the Pearson correlation between the **requested incident energy** and
# the **total generated deposited energy**.
#
# Steps:
#
# 1. pick `req_energy` — a range of incident energies across the dataset,
# 2. map them to bins with `energy_to_bin`, generate with `sample_showers`,
# 3. sum each generated shower to get `gen_total` (GeV),
# 4. compute Pearson `r` between `req_energy` and `gen_total`.
#
# Return `response_r` (a number). A well-conditioned model gives `r` close to 1 —
# see how close yours gets (diffusion takes real training to condition well).

# %%
# cadence:checkpoint ex2-energy-response manual
# cadence:starter
req_energy = np.linspace(incident.min() + 1, incident.max() - 1, 200)
gen = sample_showers(energy_to_bin(req_energy))
# total deposited energy per generated shower (sum each image over its cells):
gen_total = ...
# Pearson correlation between requested energy and generated total energy:
response_r = ...
print("energy-response Pearson r:", round(response_r, 3))
# cadence:end
# cadence:hint gen_total = gen.sum(axis=(1, 2, 3)); response_r = float(np.corrcoef(req_energy, gen_total)[0, 1]).

req_energy = np.linspace(incident.min() + 1, incident.max() - 1, 200)
gen = sample_showers(energy_to_bin(req_energy))
gen_total = gen.sum(axis=(1, 2, 3))
response_r = round(float(np.corrcoef(req_energy, gen_total)[0, 1]), 3)
print("energy-response Pearson r:", response_r)

response_r
# Out:
# energy-response Pearson r: 0.151
# 0.151

# %%
# energy response: generated deposited energy vs the requested incident energy
plt.figure(figsize=(5, 4))
plt.scatter(req_energy, gen_total, s=8, alpha=0.5)
plt.xlabel("requested incident energy [GeV]")
plt.ylabel("generated deposited energy [GeV]")
plt.title(f"energy response  (Pearson r = {response_r:.3f})")
plt.show()

# %% [markdown]
# ### Exercise 3 — Calibration: deposited / incident
#
# The response tells us the *trend* is right; calibration tells us the *scale*. For
# a sampling calorimeter the deposited energy is a roughly **linear** function of
# the incident energy, so the ratio `deposited / incident` is approximately
# constant — the "sampling fraction".
#
# Using the `req_energy` and `gen_total` from Exercise 2, compute the **mean of the
# per-shower ratio** `gen_total / req_energy`. Return `mean_ratio` (a number).

# %%
# cadence:checkpoint ex3-calibration manual
# cadence:starter
# the mean of the per-shower deposited/incident ratio  (gen_total / req_energy):
mean_ratio = ...
print("mean deposited/incident ratio:", round(mean_ratio, 3))
# cadence:end
# cadence:hint mean_ratio = float(np.mean(gen_total / req_energy)).

mean_ratio = round(float(np.mean(gen_total / req_energy)), 3)
print("mean deposited/incident ratio:", mean_ratio)

mean_ratio
# Out:
# mean deposited/incident ratio: 8.643
# 8.643

# %%
# the per-shower deposited/incident ratio — the (roughly constant) sampling fraction
ratios = gen_total / req_energy
plt.figure(figsize=(5, 3))
plt.hist(ratios, bins=30)
plt.axvline(mean_ratio, color="k", ls="--", label=f"mean = {mean_ratio:.3f}")
plt.xlabel("deposited / incident energy"); plt.legend(); plt.show()

# %% [markdown]
# ### Exercise 4 — Look at a shower, measure its sparsity
#
# Calorimeter showers are **sparse**: most cells are empty, energy concentrates in
# a compact core. Generate a single high-energy shower, display the image (log
# scale), and compute its **sparsity**: the fraction of cells whose energy is above
# a small threshold (`1e-3` GeV).
#
# Return `active_fraction` (a number in `[0, 1]`).

# %%
# cadence:checkpoint ex4-sparsity manual
# cadence:starter
one = sample_showers(np.array([N_EBINS - 1]))[0, 0]   # one high-energy shower, (IMG, IMG) GeV
# the "active-cell fraction": fraction of cells with energy above 1e-3 GeV:
active_fraction = ...
print("active-cell fraction:", round(active_fraction, 3))
# cadence:end
# cadence:hint active_fraction = float((one > 1e-3).mean()).

one = sample_showers(np.array([N_EBINS - 1]))[0, 0]
active_fraction = round(float((one > 1e-3).mean()), 3)
print("active-cell fraction:", active_fraction)

active_fraction
# Out:
# active-cell fraction: 1.0
# 1.0

# %%
# your generated shower on a log scale — sparse, with a compact energy core
plt.figure(figsize=(4, 4))
plt.imshow(np.log1p(one), cmap="inferno")
plt.colorbar(label="log(1 + E[GeV])")
plt.title(f"generated shower  (active cells = {active_fraction:.2f})")
plt.axis("off"); plt.show()

# %% [markdown]
# ### Exercise 5 — Submit your energy-spectrum spine
#
# Our recurring habit: compare a **1-D summary** of generated vs real. The cell
# overlays the **total deposited energy** spectrum — the real showers against a
# matched set of generated ones (sampled at the real events' energy bins) — and
# **submits your plot** so the teacher can see how well your generator matches the
# physics.

# %%
# cadence:checkpoint ex5-energy-spine manual
# cadence:starter
real_total = showers.sum(axis=(1, 2, 3))
gen_match = sample_showers(ebin[:1000]).sum(axis=(1, 2, 3))
bins = np.linspace(0, real_total.max(), 40)
plt.figure(figsize=(5, 4))
plt.hist(real_total[:1000], bins=bins, alpha=0.5, label="real", density=True)
plt.hist(gen_match, bins=bins, alpha=0.5, label="generated", density=True)
plt.xlabel("total deposited energy [GeV]"); plt.ylabel("density")
plt.title("total-energy spectrum: real vs generated"); plt.legend()
fig = plt.gcf(); plt.show()

# submit your spectrum plot for the teacher to see:
submit_image("ex5-energy-spine", fig)
# cadence:end

real_total = showers.sum(axis=(1, 2, 3))
gen_match = sample_showers(ebin[:1000]).sum(axis=(1, 2, 3))
bins = np.linspace(0, real_total.max(), 40)
plt.figure(figsize=(5, 4))
plt.hist(real_total[:1000], bins=bins, alpha=0.5, label="real", density=True)
plt.hist(gen_match, bins=bins, alpha=0.5, label="generated", density=True)
plt.xlabel("total deposited energy [GeV]"); plt.ylabel("density")
plt.title("total-energy spectrum: real vs generated"); plt.legend(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 18
#      14 # submit_image("ex5-energy-spine", fig)
#      15 # cadence:end
#      16
#      17 real_total = showers.sum(axis=(1, 2, 3))
# ---> 18 gen_match = sample_showers(ebin[:1000]).sum(axis=(1, 2, 3))
#      19 bins = np.linspace(0, real_total.max(), 40)
#      20 plt.figure(figsize=(5, 4))
#      21 plt.hist(real_total[:1000], bins=bins, alpha=0.5, label="real", density=True)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# Cell In[22], line 10, in sample_showers(bins, n_steps)
#       6     labels = torch.as_tensor(np.asarray(bins), dtype=torch.long, device=device)
#       7     x = torch.randn(len(labels), 1, IMG, IMG, device=device)
#       8     scheduler.set_timesteps(n_steps)
#       9     for t in scheduler.timesteps:
# ---> 10         eps = unet(x, t, class_labels=labels).sample
#      11         x = scheduler.step(eps, t, x).prev_sample
#      12     gev = from_image(x.cpu().numpy())
#      13     return np.clip(gev, 0.0, None)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/diffusers/models/unets/unet_2d.py:336, in UNet2DModel.forward(self, sample, timestep, class_labels, return_dict)
#     334         sample, skip_sample = upsample_block(sample, res_samples, emb, skip_sample)
#     335     else:
# --> 336         sample = upsample_block(sample, res_samples, emb)
#     338 # 6. post-process
#     339 sample = self.conv_norm_out(sample)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/diffusers/models/unets/unet_2d_blocks.py:2566, in UpBlock2D.forward(self, hidden_states, res_hidden_states_tuple, temb, upsample_size, *args, **kwargs)
#    2564         hidden_states = self._gradient_checkpointing_func(resnet, hidden_states, temb)
#    2565     else:
# -> 2566         hidden_states = resnet(hidden_states, temb)
#    2568 if self.upsamplers is not None:
#    2569     for upsampler in self.upsamplers:
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/diffusers/models/resnet.py:373, in ResnetBlock2D.forward(self, input_tensor, temb, *args, **kwargs)
#     371     if self.training:
#     372         input_tensor = input_tensor.contiguous()
# --> 373     input_tensor = self.conv_shortcut(input_tensor)
#     375 output_tensor = (input_tensor + hidden_states) / self.output_scale_factor
#     377 return output_tensor
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/ml4hep-venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:

# %% [markdown]
# ### Exercise 6 — Did the conditioning work? (reflection)
#
# You built a **conditional** diffusion model and measured it with the physics
# checks. Diffusion is data- and compute-hungry, so a short run may not fully learn
# the conditioning — and these metrics are exactly what *tell you* whether it did.
# Write 2–3 sentences and submit:
#
# - Look at your energy response (Exercise 2): a well-conditioned model gives
#   r ≈ 1. How close did yours get, and — if it fell short — what would you change
#   to improve it (more epochs, more data, fewer energy bins)?
# - Why does passing the binned incident energy as `class_labels` make the model
#   energy-aware, where an *unconditional* diffusion model couldn't be?

# %%
# cadence:checkpoint ex6-reflect manual
# cadence:starter
# Your reflection (2-3 sentences), then run the cell to submit:
#   * how close did your energy response (Exercise 2) get to r ~ 1, and if it fell
#     short, what would you change (more epochs / data / fewer energy bins)?
#   * why does conditioning on the energy bin (class_labels) make the model
#     energy-aware, where an unconditional model couldn't be?
# cadence:end

# %% [markdown]
# ## Recap
#
# - A calorimeter shower is an **energy image** — a second LHC data modality beyond
#   jets, and the target of the **CaloChallenge** fast-simulation effort.
# - We trained a **conditional diffusion** model: a `diffusers` UNet with energy-bin
#   **class embeddings**, trained with the usual **predict-the-noise** MSE.
# - The physics checks that matter: the **energy response** (generated energy tracks
#   the requested energy, high Pearson r), the **calibration ratio**
#   (deposited/incident ≈ constant), and shower **sparsity**.
# - Crucially, the physics checks **diagnose** the generator: if the response
#   falls short of 1, the model hasn't learned the conditioning yet — real ML is
#   knowing your generator isn't good, which is exactly what notebook 05 is about.
# - The recurring **1-D spine** — here the total-energy spectrum — shows diffusion,
#   like the VAE (01) and GAN (02), works hardest in the **tails**.

# %% [markdown]
# <!-- cadence:hide -->
# ## Generate the cadence notebooks
#
# Run this **after** *Run All* above, so every exercise's answer value is in the kernel. `%cadence_autoregister` auto-detects each `##`-headed exercise, registers a checkpoint from the cell's final value, and writes `<this>_registered.ipynb` — which in turn writes the student notebook via the `%cadence_scaffold` cell it appends.
# <!-- cadence:end -->

# %%
# %cadence_autoregister --reveal-after 4
# Out:
# <div style="font-size: 0.85em; color: #334155; margin-bottom: 4px;">Detected notebook: <code>/Users/liv/teaching/ml4hep/gen-hep-notebooks/notebooks/04_diffusion_calo.ipynb</code></div>
#             <div style="border: 1px solid #15803d; border-radius: 6px;
#                         padding: 12px 14px; margin: 8px 0; background: #f0fdf4;
#                         line-height: 1.5; color: #1f2937;">
#                 <div style="font-weight: 600; color: #15803d; margin-bottom: 6px;">
#                     ✅ Wrote <code>/Users/liv/teaching/ml4hep/gen-hep-notebooks/notebooks/04_diffusion_calo_registered.ipynb</code>
#                 </div>
#                 <div style="font-size: 0.9em; color: #334155; margin-bottom: 8px;">
#                     6 checkpoint(s) detected (manual mode) · solutions reveal after 4 attempts ·
#                     lesson "<code>04 Diffusion Calo</code>"
#                 </div>
#                 <table style="font-size: 0.85em; border-collapse: collapse; margin-top: 4px;">
#                     <thead><tr style="color: #334155;">
#                         <th style="text-align: left; padding: 2px 8px;">id</th>
#                         <th style="text-align: left; padding: 2px 8px;">comparator</th>
#                         <th style="text-align: left; padding: 2px 8px;">expected</th>
#                     </tr></thead>
#                     <tbody><tr><td style="padding: 2px 8px;"><code>ex1-calo-train</code></td><td style="padding: 2px 8px; color: #334155;">numeric</td><td style="padding: 2px 8px; font-family: monospace;">0.0792</td></tr><tr><td style="padding: 2px 8px;"><code>ex2-energy-response</code></td><td style="padding: 2px 8px; color: #334155;">numeric</td><td style="padding: 2px 8px; font-family: monospace;">0.151</td></tr><tr><td style="padding: 2px 8px;"><code>ex3-calibration</code></td><td style="padding: 2px 8px; color: #334155;">numeric</td><td style="padding: 2px 8px; font-family: monospace;">8.643</td></tr><tr><td style="padding: 2px 8px;"><code>ex4-sparsity</code></td><td style="padding: 2px 8px; color: #334155;">numeric</td><td style="padding: 2px 8px; font-family: monospace;">1.0</td></tr><tr><td style="padding: 2px 8px;"><code>ex5-energy-spine</code></td><td style="padding: 2px 8px; color: #334155;">manual</td><td style="padding: 2px 8px; font-family: monospace;">—</td></tr><tr><td style="padding: 2px 8px;"><code>ex6-reflect</code></td><td style="padding: 2px 8px; color: #334155;">manual</td><td style="padding: 2px 8px; font-family: monospace;">—</td></tr></tbody>
#                 </table>
#
#                 <div style="margin-top: 8px; padding: 8px 10px; background: #fffbeb; border-left: 3px solid #b45309; font-size: 0.85em; color: #1f2937;"><strong>⚠ 2 advisories:</strong><ul style="margin: 4px 0 0 0; padding-left: 20px;"><li>checkpoint `ex5-energy-spine`: solution reveals at attempt 4 but no hint is registered — students go straight from wrong → worked solution with nothing in between. Add `# cadence:hint <text>` in the same cell for a gentler nudge first.</li><li>checkpoint `ex6-reflect`: solution reveals at attempt 4 but no hint is registered — students go straight from wrong → worked solution with nothing in between. Add `# cadence:hint <text>` in the same cell for a gentler nudge first.</li></ul></div>
#                 <div style="margin-top: 10px; font-size: 0.85em; color: #334155;">
#                     Next: open <code>04_diffusion_calo_registered.ipynb</code>, run the setup cell at the
#                     top to register the lesson, then run <code>%cadence_scaffold</code> from
#                     inside it to produce the student notebook.
#                 </div>
#             </div>
# /Users/liv/teaching/ml4hep/gen-hep-notebooks/notebooks/04_diffusion_calo_registered.ipynb
